# %%
#-------------------------
#     Task Instructios
#-------------------------
# Let users move through rooms based on user input and get descriptions of each room. Key points:
# - establish the direction in which the player can move
# - a way to track how far the user has moved (and therfore which room they are in)
# - print out a description of the room
# - create walls around rooms and let users know if they can not move in a particular direction
#--------------------------

# %%
#--------------------------
#     Initial Thoughts
#--------------------------
# Create a visual map to follow before coding
# Each room is its own function potentialy
# The location is stored?

# %%
# This imports a library that will allow us to clear the cell output so we can see only the fresh information for a new room
from tkinter import W
from IPython.display import clear_output


# Global direction variables
w_north = any 
s_south = any
a_east =  any
d_west =  any

# Tracking the current room [name of current room, description of current room, room to the norn, room to the south, room to the east, room to the west]
current_room = ["Rm1", "the starter room", "Rm2","Rm4","Rm5","Rm3"]


# We use this repeatedly to ask the user which direction they want to move in 
def user_input():
    user_direction = input("Where would you like to go? Type lowercase 'w' for North, 's' for South, 'a' for West or 'd' for East" )
    #next_room = function
    if user_direction == "w": # north
       next_room = current_room[2]
    elif user_direction == "s": # south
        next_room = current_room[3]
    elif user_direction == "a": # east
        next_room = current_room[4]
    elif user_direction == "d": # west
        next_room = current_room[5]
    else:
        #for i in range(10):
            #clear_output(wait=True)
            print("Sorry I dont recognise that please try again. Type a lowercase 'w' for North, 's' for South, 'd' for East or 'a' for West" )
            user_input()
    #return user_direction

# When a direction hits a wall then tell the user they can not go in that direction
def wall():
    print("You can not go in this direction.")
    user_input()

#--------------------------------------
# Each room is labeled as a function
#--------------------------------------

#   ROOM 1
def Rm1():
    #clear_output(wait=True)
    print(f"Your in room one.\n"
     "...description of room... \n"
     " pick a direction to move in...")
    #w_north = Rm2()
    #s_south = Rm4()
    #a_east =  Rm5()
    #d_west =  Rm3()
    current_room = ["Rm1", "the starter room", "Rm2","Rm4","Rm3","Rm5"]
    user_input() 
         

#   ROOM 2
def Rm2():
    #clear_output(wait=True)
    print("Your in room two \n"
    "...description of room... \n"
     " pick a direction to move in...")
    #w_north = wall()
    #s_south = Rm1()
    #a_east = Rm6()
    #d_west = Rm9()
    user_input() 
           

#   ROOM 3
def Rm3():
    print("Your in room three.\n"
    "...description of room... \n"
     " pick a direction to move in...")
    #w_north = Rm9()
    #s_south = Rm8()
    #a_east = Rm1()
    #d_west = wall()
    user_input() 


# ROOM 4
def Rm4():
    print("Your in room four. \n"
    "...description of room... \n"
     " pick a direction to move in...")

# ROOM 5
def Rm5():
    print("Your in room five. \n"
    "...description of room... \n"
     " pick a direction to move in...")


# ROOM 6
def Rm6():
    print("Your in room six. \n"
    "...description of room... \n"
     " pick a direction to move in...")

# ROOM 7
def Rm7():
    print("Your in room seven. \n"
    "...description of room... \n"
     " pick a direction to move in...")

# ROOM 8
def Rm8():
    print("Your in room eight. \n"
    "...description of room... \n"
     " pick a direction to move in...")

# ROOM 9
def Rm9():
    print("Your in room nine. \n"
    "...description of room... \n"
     " pick a direction to move in...")

# %%
#------------------------
# Rooms in a list instead
#------------------------
# column descriptions...
# 0 = room number
# 1 = short room description
# 2 = room to the north 
# 3 = room to the south
# 4 = room to the east
# 5 = room to the west
# 6 = long description  

space = [['Rm1', "s.description", 'Rm2', 'Rm4', 'Rm3', 'Rm5', "Your in room eight. \n"
    "...description of room... \n"
     " pick a direction to move in..."], ['Rm2', ]]
location = space.index()
print(location)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [6], line 16
#       1 #------------------------
#       2 # Rooms in a list instead
#       3 #------------------------
#    (...)
#      10 # 5 = room to the west
#      11 # 6 = long description
#      13 space = [['Rm1', "s.description", 'Rm2', 'Rm4', 'Rm3', 'Rm5', "Your in room eight. \n"
#      14     "...description of room... \n"
#      15      " pick a direction to move in..."], ['Rm2', ]]
# ---> 16 location = space.index()
#      17 print(location)
#
# TypeError: index expected at least 1 argument, got 0

# %%
# Tracking the current room [name of current room, description of current room, room to the norn, room to the south, room to the east, room to the west]
current_room = ["Rm1", "the starter room", "Rm2","Rm4","Rm5","Rm3"]


# We use this repeatedly to ask the user which direction they want to move in 
def user_input():
    user_direction = input("Where would you like to go? Type lowercase 'w' for North, 's' for South, 'a' for West or 'd' for East" )
    #while user_direction != "w" or user_direction != "s" or user_direction != "a" or user_direction != "d" :
        if user_direction == "w": # north
            next_room = current_room[2]
        elif user_direction == "s": # south
            next_room = current_room[3]
        elif user_direction == "a": # east
            next_room = current_room[4]
        elif user_direction == "d": # west
            next_room = current_room[5]
        else:
            print("Sorry I dont recognise that please try again. Type a lowercase 'w' for North, 's' for South, 'd' for East or 'a' for West" )
    print(next_room)

user_input()
