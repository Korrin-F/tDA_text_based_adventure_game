# %%
#-------------------------
#     Task Instructios
#-------------------------
# Let users move through rooms based on user input and get descriptions of each room. Key points:
# - establish the direction in which the player can move
# - a way to track how far the user has moved (and therfore which room they are in)
# - print out a description of the room
# - create walls around rooms and let users know if they can not move in a particular direction
#--------------------------

# %%
#--------------------------
#     Initial Thoughts
#--------------------------
# Create a visual map to follow before coding
# Each room is its own function potentialy
# The location is stored?

# %%
# This imports a library that will allow us to clear the cell output so we can see only the fresh information for a new room
from tkinter import W
from IPython.display import clear_output
# import the time library to add delays in my code execution
import time

# Global direction variables
#w_north = any 
#s_south = any
#a_east =  any
#d_west =  any



# Tracking the current room [name of current room, description of current room, room to the norn, room to the south, room to the east, room to the west]
room = ["Rm0", "a large courtyard.", "Rm1","wall","wall","wall"]

def update_room(r,d,n,s,e,w):
    room = [r,d,n,s,e,w] #["Rm0", "a large courtyard.", "Rm1","wall","wall","wall"]
    return room

#def room_print():
    #clear_output(wait=True)
    #print(f"You have arrived in {current_room[1]}.")

''' -----------------------
      User Movement
------------------------'''


# We use this repeatedly to ask the user which direction they want to move in 
def user_input(current_room):
    user_direction = input("Where would you like to go? Type lowercase 'w' for North, 's' for South, 'a' for West or 'd' for East" )
    
    if user_direction == "w": # north
        next_room = current_room[2]
        eval(next_room + "()") # calls the function by its string name...   NAILED IT
    elif user_direction == "s": # south
        next_room = current_room[3]
        eval(next_room + "()") # calls the function by its string name...   NAILED IT
    elif user_direction == "a": # east
        next_room = current_room[4]
        eval(next_room + "()") # calls the function by its string name...   NAILED IT
    elif user_direction == "d": # west
        next_room = current_room[5]
        eval(next_room + "()") # calls the function by its string name...   NAILED IT
    elif user_direction == "xxx": # to help with debugging
        print("manual end")
    else:
        print("Sorry I dont recognise that please try again. Type a lowercase 'w' for North, 's' for South, 'd' for East or 'a' for West" )
        user_input()
    #print(next_room)
    #
     
# When a direction hits a wall then tell the user they can not go in that direction
def wall():
    print("You can not go in this direction.")
    user_input(room)

# %%
#------------------------
# Rooms defined
#------------------------
def Rm26():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm26", "the 26th room", "Rm25","wall","wall","Rm1"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm25():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm25", "the 25th room", "Rm23","Rm26","wall","Rm3"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm24():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm24", "the 24th room", "Rm21","wall","wall","Rm23"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm23():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm23", "the 23rd room", "Rm22","Rm25","Rm24","Rm5"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm22():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm22", "the 22nd room", "Rm19","Rm23","Rm21","wall"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm21():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm21", "the 21st room", "Rm20","Rm24","wall","Rm22"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm20():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm20", "the 20th room", "wall","Rm21","wall","Rm19"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm19():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm19", "the 19th room", "Rm18","Rm22","Rm20","wall"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm18():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm18", "the 18th room", "wall","Rm19","wall","Rm17"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm17():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm17", "the 17th room", "wall","wall","Rm18","Rm15"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm16():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm16", "the 16th room", "Rm15","wall","wall","wall"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm15():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm15", "the 15th room", "wall","Rm16","Rm17","Rm14"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm14():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm14", "the 14th room", "wall","Rm12","Rm15","Rm13"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm13():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm13", "the 13th room", "wall","Rm11","Rm14","wall"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm12():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm12", "the 12th room", "Rm14","Rm9","wall","Rm11"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm11():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm11", "the 11th room", "Rm13","Rm10","Rm12","wall"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm10():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm10", "the 10th room", "Rm11","wall","Rm9","wall"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm9():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm9", "the 9th room", "Rm12","Rm8","wall","Rm10"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm8():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm8", "the 8th room", "Rm9","Rm7","Rm6","wall"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm7():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm7", "the seventh room", "Rm8","wall","Rm4","wall"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm6():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm6", "the sixth room", "wall","Rm4","Rm5","Rm8"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm5():
    clear_output(wait=True)
    time.sleep(2)
    current_room = ["Rm5", "the fifth room", "wall","Rm3","Rm23","Rm6"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(2)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm4():
    clear_output(wait=True)
    #time.sleep(2)
    #current_room("Rm4", "the fourth room", "Rm6","Rm2","Rm3","Rm7")
    current_room = ["Rm4", "the fourth room", "Rm6","Rm2","Rm3","Rm7"]
    print(f"You have arrived in {room[1]}.\n")
    time.sleep(1)
    print("Welcome to this room. Story coming soon.")
    user_input()

def Rm3():
    clear_output(wait=True)
    #time.sleep(2)
    #current_room("Rm3", "the third room", "Rm5","Rm1","Rm25","Rm4")
    current_room = ["Rm3", "the third room", "Rm5","Rm1","Rm25","Rm4"]
    print(f"You have arrived in {room[1]}.")
    time.sleep(1)
    print("Welcome to this room. Story coming soon.")
    update_room(current_room)
    user_input(current_room)

def Rm2():
    clear_output(wait=True)
    time.sleep(1)
    #current_room("Rm2","the second room","Rm4","wall","Rm1","wall")
    current_room = ["Rm2", "the second room", "Rm4","wall","Rm1","wall"]
    print(f"You have arrived in {current_room[1]}.\n")
    time.sleep(1)
    print("Welcome to this room. Story coming soon.")
    update_room(current_room)
    user_input(current_room)

def Rm1():
    clear_output(wait=True)
    time.sleep(1)
    #current_room("Rm1","the first room","Rm3","Rm0","Rm26","Rm2")
    current_room = ["Rm1", "the first room", "Rm3","Rm0","Rm26","Rm2"]
    print(f"You have arrived in {room[1]}.")
    time.sleep(1)
    print("Welcome to this room. Story coming soon.")
    update_room(current_room)
    user_input(current_room)

def Rm0():
    clear_output(wait=True)
    time.sleep(1)
    #current_room("Rm0","a large courtyard.","Rm1","wall","wall","wall")
    current_room = ["Rm0", "a large courtyard.", "Rm1","wall","wall","wall"]
    print(f"You have arrived in {room[1]}.")
    time.sleep(1)
    print("Welcome to this room. Story coming soon.")
    update_room(current_room)
    user_input(current_room)

# %%
# to skip the intro
current_room = ["Rm0", "a large courtyard.", "Rm1","wall","wall","wall"]
user_input(current_room)

#  current_room(r,d,n,s,e,w)
# Out:
# You have arrived in a large courtyard..
# Welcome to this room. Story coming soon.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [34], line 3
#       1 # to skip the intro
#       2 current_room = ["Rm0", "a large courtyard.", "Rm1","wall","wall","wall"]
# ----> 3 user_input(current_room)
#
# Cell In [23], line 25, in user_input(current_room)
#      23 if user_direction == "w": # north
#      24     next_room = current_room[2]
# ---> 25     eval(next_room + "()") # calls the function by its string name...   NAILED IT
#      26 elif user_direction == "s": # south
#      27     next_room = current_room[3]
#
# File <string>:1
#
# Cell In [25], line 240, in Rm1()
#     238 time.sleep(1)
#     239 print("Welcome to this room. Story coming soon.")
# --> 240 user_input()
#
# TypeError: user_input() missing 1 required positional argument: 'current_room'

# %%
'''--------------------
Start the game here
-----------------------'''

# Intro text
def intro_p1():
    print("You wake up...\n")
    time.sleep(2)
    print("Your head is pounding and your vision spins...\n")
    time.sleep(3)
    print("As your vision starts to clear you realise you are lying on the ground \n"
    "so you slowly get up on shaky legs. Instinctively wiping off the front of your clothes \n"
    "only to realise you are wearing a hospital gown.\n")
    time.sleep(9)
    print("Your memory fails you as you try and recall how you got here,\n"
    "what day it is, or even who you are.\n")
    time.sleep(7)
    print("A burning throb in your left arm steals your attention as you notice a \n"
    "fresh angry burn running down your forearm and ending at your wrist, where you see what \n"
    "looks like a medical wrist band.\n")
    time.sleep(9)
    print("Trying to ignore the pain in your arm and head you look in closer, \n"
    "hoping to find out any information that could help explain your circumstance.\n")
    #time.sleep(7)
    
def intro_p2():
    print("To your disappointment, the wristband has been melted beyond repair and any text that \nremains is illegible.\n")
    time.sleep(4)
    print("Taking a deep breath, you lift your head to look around and you find yourself in the\n"
    "centre of a large, manicured lawn. The grass is cold and slightly damp on your bare feet and\n"
    "the air is cool under an overcast sky.\n")
    time.sleep(10)
    print("You squint your eyes as bright light hits them, bringing up your hand in protection.\n"
    "You notice the light is coming from the surface of an impossibly high wall, made of some sort\n"
    "of reflective material.\n") 
    time.sleep(10)
    print("The wall appears to be seamless as you follow it around with your eyes noticing it fully\n" 
    "encloses the field. You continue to spin and see that it connects with a tall windowed building\n" 
    "that appears to be made of the same reflective material.\n")
    time.sleep(9)
    print("At the base of the building there appears to be a large open doorway with a small staircase leading\n"
    "up to it.\n")
    time.sleep(5)
    print("How do you proceed?")
    user_input()
    
intro_p1()
time.sleep(10)
clear_output(wait=True)
intro_p2()
# Out:
# You have arrived in the first room.
#
# Welcome to this room. Story coming soon.

# %%
# debug

#["Rm0", "a large courtyard.", "Rm1","wall","wall","wall"]



''' -----------------------
      User Movement
------------------------'''


# We use this repeatedly to ask the user which direction they want to move in 
def u_input(cr_room):
    user_direction = input("Where would you like to go? Type lowercase 'w' for North, 's' for South, 'a' for West or 'd' for East" )
    retry = cr_room
    print(f"made it step one cr_room: {cr_room}")

    if cr_room[:] == "wall":
        print("You can not go in this direction.")
        u_input(retry)
    elif user_direction == "w":   # north
        eval(cr_room[2] + "()") # calls the function by its string name...   NAILED IT
    elif user_direction == "s": # south
        eval(cr_room[3] + "()") # calls the function by its string name...   NAILED IT
    elif user_direction == "d": # east
        eval(cr_room[4] + "()") # calls the function by its string name...   NAILED IT
    elif user_direction == "a": # west
        eval(cr_room[5] + "()") # calls the function by its string name...   NAILED IT
    elif user_direction == "xxx": # to help with debugging
        print("manual end")
    elif user_direction == "print":
        print(f"retry = {retry}")
        print(f"cr_room = {cr_room}")
    else:
        print("Sorry I dont recognise that please try again. Type a lowercase 'w' for North, 's' for South, 'd' for East or 'a' for West" )
        u_input(retry)
    
     


def room_2():
    #clear_output(wait=True)
    cr_room = ["room_2", "the second room", "room_4","wall","room_1","wall"]
    print(room_2)
    u_input(cr_room)

def room_1():
    #clear_output(wait=True)
    cr_room = ["room_1", "the first room", "room_3","room_0","room_26","room_2"]
    print(room_1)
    u_input(cr_room)

def room_0():
    #clear_output(wait=True)
    cr_room = ["room_0", "a large courtyard.", "room_1","wall","wall","wall"]
    print(room_0)
    u_input(cr_room)

room_0()
# Out:
# <function room_0 at 0x1102367a0>
# made it step one cr_room: ['room_0', 'a large courtyard.', 'room_1', 'wall', 'wall', 'wall']
# <function room_1 at 0x110442170>
# made it step one cr_room: ['room_1', 'the first room', 'room_3', 'room_0', 'room_26', 'room_2']
# <function room_2 at 0x110441d80>
# made it step one cr_room: ['room_2', 'the second room', 'room_4', 'wall', 'room_1', 'wall']
# You can not go in this direction.
# You can not go in this direction.
# Sorry I dont recognise that please try again. Type a lowercase 'w' for North, 's' for South, 'd' for East or 'a' for West
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [43], line 59
#      56     print(room_0)
#      57     u_input(cr_room)
# ---> 59 room_0()
#
# Cell In [43], line 57, in room_0()
#      55 cr_room = ["room_0", "a large courtyard.", "room_1","wall","wall","wall"]
#      56 print(room_0)
# ...
